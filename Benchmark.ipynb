# %%
from pic.benchmark import Benchmark_results
import tkinter as tk
from tkinter import filedialog
import os

# %%
# %gui tk

root = tk.Tk()
root.withdraw()

currentPath = os.getcwd()
filename = filedialog.askdirectory(parent=root, initialdir="./data")
print(filename)

# %%
view = Benchmark_results(1, filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 view = Benchmark_results(1, filename)
#
# File c:\Users\super\Desktop\1D-PIC-EA-23\pic\benchmark.py:24, in Benchmark_results.__init__(self, case, results)
#      23 def __init__(self, case, results):
# ---> 24     self.simu = Hdf5Viewer(results)
#      25     file = os.path.join("benchmark", f"case{case}.dat")
#      26     with open(file, "r") as infile:
#
# File c:\Users\super\Desktop\1D-PIC-EA-23\pic\Hdf5Viewer.py:49, in Hdf5Viewer.__init__(self, folder, only)
#      46 self.lenghts = {"Gamma": 2, "Gamma_yz": 1}
#      47 self.data_size = {"V": 3, "P": 6, "q": 3}
#      48 self.parameters: Dict[str, Any] = pickle.load(
# ---> 49     open(os.path.join(folder, "parameters.pkl"), "rb")
#      50 )
#      51 self.folder = Path(folder)
#      52 self.dx = (self.parameters["Lx"] / self.parameters["Nx"]).si
#
# FileNotFoundError: [Errno 2] No such file or directory: 'parameters.pkl'

# %%
view.compare_ne()

# %%
view.compare_ni()

# %%
view.compare_eepf()
